# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from sklearn.metrics import log_loss, roc_auc_score
from sklearn.model_selection import TimeSeriesSplit
import matplotlib.pyplot as plt
#Load data 
df_clean = pd.read_csv("/Users/arttusokka/Documents/AThesis/Prediciting-ATP-matches-outcome/data/clean_and_raw/atp_matches_2000_2019_clean.csv")

#JONIN ML KURSSIN PROJEKTI -> RANDOM FOREST
